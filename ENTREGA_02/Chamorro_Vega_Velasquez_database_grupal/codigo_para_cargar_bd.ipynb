# %%
import pandas as pd

bd = pd.read_csv("/content/drive/MyDrive/csvs/lagrimas_ghibli.csv", sep=",")

display(bd)
# Out:
#                       Película   Año Timestamp  Duración (seg.)  \
# 0         Castillo en el cielo  1886   1:33:03                1
# 1         Castillo en el cielo  1886   1:34:06                1
# 2             Mi Vecino Totoro  1988   0:43:19                5
# 3             Mi Vecino Totoro  1988   1:08:24               26
# 4             Mi Vecino Totoro  1988   1:09:49               21
# 5             Mi Vecino Totoro  1988   1:18:02               18
# 6             Mi Vecino Totoro  1988   1:21:15               22
# 7   Kiki: Entregas a domicilio  1989   0:21:46                7
# 8   Kiki: Entregas a domicilio  1989   1:20:21                3
# 9   Kiki: Entregas a domicilio  1989   1:31:05               11
# 10  Kiki: Entregas a domicilio  1989   1:35:20               49
# 11  Kiki: Entregas a domicilio  1989   1:39:20                4
# 12                 Porco Rosso  1992   1:03:47                3
# 13                 Porco Rosso  1992   1:25:47               10
# ...

# %%
import os

# List files in your Google Drive
# Adjust the path below if you know the file is in a specific subfolder
for root, dirs, files in os.walk("/content/drive/MyDrive/"):
    for file in files:
        if "lagrimas_ghibli.csv" in file:
            print(os.path.join(root, file))
# Out:
# /content/drive/MyDrive/Colab Notebooks/lagrimas_ghibli.csv
